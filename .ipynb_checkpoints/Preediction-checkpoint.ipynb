# %%
import pandas as pd
import numpy as np
import pickle

# %%
pike = pickle.load(open('pipe.pkl','rb'))

# %%
input_data = pd.DataFrame(
    [[
        'Dell',
        'Ultrabook',
        14.0,
        'Windows 10',
        1.70,
        'Intel Core i5',
        8,
        256,
        'SSD',
        'NO',
        'NO',
        'Intel UHD 620'
    ]],
    columns=['Company', 'TypeName', 'Inches', 'OpSys', 'W', 'fwe', 'ram', 'int', '1',
       '4', '3', 'efe']
)

# %%
pike.predict(input_data)
# Out:
# array([50950.4673312])
